# %%
#

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.signal import find_peaks

# %%
data = np.loadtxt("/Users/Igor/PycharmProjects/ManchesterBioinformaticsCourse_Student/Day2/Code/breathing_data/p09.csv",
                delimiter=',')
np.shape(data)
# Out:
# (2, 1319)

# %%
plt.scatter(data[0], data[1], marker='o', alpha=0.2, color="purple", linewidths=0.05)
plt.xlabel("`First row")
plt.ylabel("Second row")
# Out:
# Text(0, 0.5, 'Second row')

# %%
data2 = np.convolve(data[0], data[1])
np.shape(data2)
# Out:
# (2637,)

# %%
plt.plot(data2)

# %%
x = data[0]
y = data[1]



plt.plot(x, y,'r-')

# %%
def smooth(y):
    #box = np.ones(box_pts)/box_pts
    box = signal.windows.hann(50)
    y_smooth = np.convolve(y, box, mode='same')/sum(box)
    return y_smooth

# %%
plt.plot(x, smooth(y), 'r-', lw=2)

# %%
plt.plot(x, smooth(y,25), 'g-', lw=1)

# %%
y2 = smooth(y)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
print(y2)
# Out:
# [0.41837314 0.45148273 0.48298894 ... 0.34847363 0.31344961 0.27965901]

# %%
plt.plot(x, y2, 'g-', lw=1)

# %%
peaks, _ = find_peaks(y2, distacne )

# %%
print(peaks)
# Out:
# [576]

# %%
print(_)
# Out:
# {'prominences': array([], dtype=float64), 'left_bases': array([], dtype=int64), 'right_bases': array([], dtype=int64)}

# %%
print(x)
# Out:
# [0.000e+00 1.000e-02 2.000e-02 ... 1.316e+01 1.317e+01 1.318e+01]

# %%
print(max(x))
# Out:
# 13.18

# %%
plt.plot(x, y)

# %%
print(_)
# Out:
# {}

# %%
_['peak_heights']
# Out:
# array([0.99314953, 1.03800727, 0.87714533, 0.92833462, 0.70700871,
#        0.36470636, 0.90885362, 0.98791101, 0.98904167, 0.96075047,
#        0.98636807, 1.00794198, 0.84707249, 0.65713137])

# %%
type(_['peak_heights'])
# Out:
# numpy.ndarray

# %%
y3 = _['peak_heights']

# %%
plt.plot(x, y, 'g-', label='raw_data', x, y2, 'b--', label='smoothed data', peaks, y3, 'ro', label='identified peaks')
plt.xlabel("Time(s)")
plt.ylabel("Breaths")
plt.legend(loc="upper left")
#plt.ylim(0, 2.0)
# Out:
#   File "<ipython-input-65-d4f56c349c22>", line 1
#     plt.plot(x, y, 'g-', label='raw_data', x, y2, 'b--', label='smoothed data', peaks, y3, 'ro', label='identified peaks')
#                                           ^
# SyntaxError: positional argument follows keyword argument

# %%
print(x2)
# Out:
# [0.99314953 1.03800727 0.87714533 0.92833462 0.70700871 0.36470636
#  0.90885362 0.98791101 0.98904167 0.96075047 0.98636807 1.00794198
#  0.84707249 0.65713137]

# %%
plt.plot(x, y, 'g-', label='raw_data')
plt.plot(x, y2, 'b--', label='smoothed data')
plt.plot(peaks, y3, 'ro', label='identified peaks')
plt.xlabel("Time(ms)")
plt.ylabel("Breaths")
plt.legend(loc="lower left")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-005f01e617d9> in <module>
#       1 plt.plot(x, y, 'g-', label='raw_data')
#       2 plt.plot(x, y2, 'b--', label='smoothed data')
# ----> 3 plt.plot(peaks, y3, 'ro', label='identified peaks')
#       4 plt.xlabel("Time(ms)")
#       5 plt.ylabel("Breaths")
#
# ~/anaconda/envs/sprint/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~/anaconda/envs/sprint/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
